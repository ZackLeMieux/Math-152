# %% [markdown]
# <a href="https://colab.research.google.com/github/ZackLeMieux/Math-152/blob/main/Midterm1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Four Divisors: Create a function four_divisors(n) that returns the list of numbers less than n which divisors are 1,p,q,n with p != q primes.
#
# Want to return a list that has as values all numbers less than n who have divisors of 1, n and two prime numbers that cannot be the same.

# %%
import math
def four_divisors(n):         #Originally I wanted to itterate through the numbers up to n, then iterate twice again
  a=1                         # for each of the numbers in order to hold a value constant and see if there was a pairing 
  b=1                         # that was less than n, whose product would be equal to whatever integer we were iterating for.
  L = list(range(0,n+1))      # I do not know how to check for primality for an arbitrary integer between 0 to n, without creating a list of primes.
  for x in range(0,n):            
    for y in range(0,x):
      for z in range(1,y+1):
        if x%z==0:
          print(z)

# %%
four_divisors(4)
# Out:
# 1
# 1
# 1

# %%
def four_divisors_primelist(n):       #My goal was to create a list of prime numbers from 0 to n, then use
  L=list(range(0,n))                  # this list to see if they were divisors of any of the numbers less
  L[0]=False                          # than n, I would then make sure that the number had exactly two primes
  L[1]=False                          # as divisors which would then be compiled into a list.
  L[::2]=[False]*[len(L[4::2])]
  L[::3] = [False]*[len(L[9::3])]

# %%
four_divisors_primelist(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-2d6330717d82> in <module>()
# ----> 1 four_divisors_primelist(10)
#
# <ipython-input-73-59e5bcf3d970> in four_divisors_primelist(n)
#       3   L[0]=False                          # than n, I would then make sure that the number had exactly two primes
#       4   L[1]=False                          # as divisors which would then be compiled into a list.
# ----> 5   L[::2]=[False]*[len(L[4::2])]
#       6   L[::3] = [False]*[len(L[9::3])]
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
# Out:
#   File "<ipython-input-60-b751f6873750>", line 2
#     while n:
#             ^
# SyntaxError: unexpected EOF while parsing

# %%
four_divisors(64)

# %% [markdown]
# itterate from 0 to n: one for loop
# then for each number we have to look at if there are two primes that divide it:
